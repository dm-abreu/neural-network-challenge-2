# %% [markdown]
# ## Part 1: Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras import layers

#  Import and read the attrition data
attrition_df = pd.read_csv('https://static.bc-edx.com/ai/ail-v-1-0/m19/lms/datasets/attrition.csv')
attrition_df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  HourlyRate  \
# 0          2  Life Sciences                        2          94
# 1          1  Life Sciences                        3          61
# 2          2          Other                        4          92
# 3          4  Life Sciences                        4          56
# 4          1        Medical                        1          40
#
#    JobInvolvement  ...  PerformanceRating RelationshipSatisfaction  \
# 0               3  ...                  3                        1
# 1               2  ...                  4                        4
# 2               2  ...                  3                        2
# 3               3  ...                  3                        3
# 4               3  ...                  3                        4
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                 8                      0               1
# 1                 1                10                      3               3
# 2                 0                 7                      3               3
# 3                 0                 8                      3               3
# 4                 1                 6                      3               3
#
#    YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                   4                        0
# 1              10                   7                        1
# 2               0                   0                        0
# 3               8                   7                        3
# 4               2                   2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 27 columns]

# %%
# Determine the number of unique values in each column.
attrition_df.nunique()
# Out:
# Age                         43
# Attrition                    2
# BusinessTravel               3
# Department                   3
# DistanceFromHome            29
# Education                    5
# EducationField               6
# EnvironmentSatisfaction      4
# HourlyRate                  71
# JobInvolvement               4
# JobLevel                     5
# JobRole                      9
# JobSatisfaction              4
# MaritalStatus                3
# NumCompaniesWorked          10
# OverTime                     2
# PercentSalaryHike           15
# PerformanceRating            2
# RelationshipSatisfaction     4
# StockOptionLevel             4
# TotalWorkingYears           40
# TrainingTimesLastYear        7
# WorkLifeBalance              4
# YearsAtCompany              37
# YearsInCurrentRole          19
# YearsSinceLastPromotion     16
# YearsWithCurrManager        18
# dtype: int64

# %%
# Create y_df with the Attrition and Department columns
y_df = attrition_df[['Attrition', 'Department']]

# %%
# Create a list of at least 10 column names to use as X data
feature_columns = [
    'Age', 'DistanceFromHome', 'Education', 'JobInvolvement',
    'HourlyRate', 'TotalWorkingYears', 'YearsAtCompany',
    'NumCompaniesWorked', 'TrainingTimesLastYear', 'PercentSalaryHike'
]


# Create X_df using your selected columns
X_df = attrition_df[feature_columns]

# Show the data types for X_df
print(X_df.dtypes)
# Out:
# Age                      int64
# DistanceFromHome         int64
# Education                int64
# JobInvolvement           int64
# HourlyRate               int64
# TotalWorkingYears        int64
# YearsAtCompany           int64
# NumCompaniesWorked       int64
# TrainingTimesLastYear    int64
# PercentSalaryHike        int64
# dtype: object

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split

# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X_df, y_df, test_size=0.2, random_state=42
)

# Display the shapes of the resulting splits
print("Training features shape:", X_train.shape)
print("Testing features shape:", X_test.shape)
print("Training labels shape:", y_train.shape)
print("Testing labels shape:", y_test.shape)
# Out:
# Training features shape: (1176, 10)
# Testing features shape: (294, 10)
# Training labels shape: (1176, 2)
# Testing labels shape: (294, 2)

# %%
# Convert your X data to numeric data types however you see fit
# Add new code cells as necessary

# %%
# Create a StandardScaler
scaler = StandardScaler()

# Fit the StandardScaler to the training data
X_train_scaled = scaler.fit_transform(X_train)

# Scale the training and testing data

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.preprocessing import OneHotEncoder

# Create a OneHotEncoder for the Department column
encoder = OneHotEncoder()

# Fit the encoder to the training data
encoder.fit(y_train[['Department']])

# Transform the 'Department' column of both training and testing data and convert to dense format
y_train_department_encoded = encoder.transform(y_train[['Department']]).toarray()
y_test_department_encoded = encoder.transform(y_test[['Department']]).toarray()


# Testing the data
print("Encoded department - training data shape:", y_train_department_encoded.shape)
print("Encoded department - testing data shape:", y_test_department_encoded.shape)
# Out:
# Encoded department - training data shape: (1176, 3)
# Encoded department - testing data shape: (294, 3)

# %%
# Instead of using OneHotEncoder for the Attrition column, directly convert 'Yes'/'No' into binary format (0 and 1)
y_train_attrition_binary = (y_train['Attrition'] == 'Yes').astype(int)
y_test_attrition_binary = (y_test['Attrition'] == 'Yes').astype(int)

# Let's get a peek at the binary encoded attrition data
print("Binary encoded attrition - training data (first 5 rows):\n", y_train_attrition_binary,
      "\n\nBinary encoded attrition - testing data (first 5 rows):\n", y_test_attrition_binary)
# Out:
# Binary encoded attrition - training data (first 5 rows):
#  1097    0
# 727     0
# 254     0
# 1175    0
# 1341    0
#        ..
# 1130    0
# 1294    0
# 860     1
# 1459    0
# 1126    0
# Name: Attrition, Length: 1176, dtype: int64
#
# Binary encoded attrition - testing data (first 5 rows):
#  1041    0
# 184     0
# 1222    1
# 67      0
# 220     0
#        ..
# 567     0
# 560     0
# 945     0
# 522     0
# 651     0
# Name: Attrition, Length: 294, dtype: int64

# %% [markdown]
# ## Create, Compile, and Train the Model

# %%
# Find the number of columns in the X training data
num_features = X_train_scaled.shape[1]
print("Number of features:", num_features)

from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

# Create the input layer
input_layer = Input(shape=(num_features,))

# Create two shared dense layers
shared_dense1 = Dense(64, activation='relu')(input_layer)  # First shared layer with 64 units
shared_dense2 = Dense(32, activation='relu')(shared_dense1)  # Second shared layer with 32 units
# shared_dense3 = Dense(32, activation='relu')(shared_dense2)  # Third shared layer with 32 units
# Out:
# Number of features: 10

# %%
# Create a branch for Department
# with a hidden layer and an output layer
# Adding a hidden layer specific to the Department prediction
department_hidden = Dense(32, activation='relu')(shared_dense2)

# Assuming the number of unique departments is known and stored as num_departments
num_departments = y_train_department_encoded.shape[1]

# Creating the output layer for the Department classification
department_output = Dense(num_departments, activation='softmax')(department_hidden)

# Create the hidden layer
num_departments = y_train_department_encoded.shape[1]

# Create the output layer
department_output = Dense(num_departments, activation='softmax', name='department_output')(department_hidden)

# Assuming you have stored your layer instances like this:
department_hidden_layer = Dense(32, activation='relu')
department_output_layer = Dense(num_departments, activation='softmax')

# %%
# Create a branch for Attrition
# with a hidden layer and an output layer

# Create the hidden layer
attrition_hidden = Dense(32, activation='relu')(shared_dense2)

# Create the output layer
attrition_output = Dense(1, activation='sigmoid', name='attrition_output')(attrition_hidden)

# %%
# Create the model
model = Model(inputs=input_layer, outputs=[department_output, attrition_output])

# Compile the model
model.compile(
    optimizer='adam',
    loss={
        'department_output': 'categorical_crossentropy',  # Ensure names match those in the model
        'attrition_output': 'binary_crossentropy'
    },
    metrics={
        'department_output': ['accuracy'],
        'attrition_output': ['accuracy']
    }
)




# Summarize the model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 10)]                 0         []
#
#  dense (Dense)               (None, 64)                   704       ['input_1[0][0]']
#
#  dense_1 (Dense)             (None, 32)                   2080      ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 32)                   1056      ['dense_1[0][0]']
#
#  dense_6 (Dense)             (None, 32)                   1056      ['dense_1[0][0]']
#
#  department_output (Dense)   (None, 3)                    99        ['dense_2[0][0]']
#
#  attrition_output (Dense)    (None, 1)                    33        ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 5028 (19.64 KB)
# Trainable params: 5028 (19.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Train the model
# Define the number of epochs and the batch size
epochs = 75
batch_size = 32

# Train the model
# Train the model with the updated binary targets
history = model.fit(
    X_train_scaled,
    [y_train_department_encoded, y_train_attrition_binary],
    validation_split=0.2,
    epochs=epochs,
    batch_size=batch_size,
    verbose=2
)
# Out:
# Epoch 1/75
# 30/30 - 11s - loss: 1.5668 - department_output_loss: 0.9962 - attrition_output_loss: 0.5706 - department_output_accuracy: 0.5000 - attrition_output_accuracy: 0.8021 - val_loss: 1.3442 - val_department_output_loss: 0.8255 - val_attrition_output_loss: 0.5187 - val_department_output_accuracy: 0.6356 - val_attrition_output_accuracy: 0.7966 - 11s/epoch - 362ms/step
# Epoch 2/75
# 30/30 - 0s - loss: 1.2519 - department_output_loss: 0.7899 - attrition_output_loss: 0.4621 - department_output_accuracy: 0.6543 - attrition_output_accuracy: 0.8404 - val_loss: 1.3087 - val_department_output_loss: 0.8017 - val_attrition_output_loss: 0.5070 - val_department_output_accuracy: 0.6314 - val_attrition_output_accuracy: 0.7966 - 261ms/epoch - 9ms/step
# Epoch 3/75
# 30/30 - 0s - loss: 1.2210 - department_output_loss: 0.7773 - attrition_output_loss: 0.4437 - department_output_accuracy: 0.6553 - attrition_output_accuracy: 0.8404 - val_loss: 1.2926 - val_department_output_loss: 0.8012 - val_attrition_output_loss: 0.4914 - val_department_output_accuracy: 0.6314 - val_attrition_output_accuracy: 0.7966 - 267ms/epoch - 9ms/step
# Epoch 4/75
# 30/30 - 0s - loss: 0.5128 - department_output_loss: 0.3229 - attrition_output_loss: 0.1899 - department_output_accuracy: 0.8883 - attrition_output_accuracy: 0.9255 - val_loss: 2.0650 - val_department_output_loss: 1.3416 - val_attrition_output_loss: 0.7234 - val_department_output_accuracy: 0.5466 - val_attrition_output_accuracy: 0.7542 - 191ms/epoch - 6ms/step
# Epoch 75/75
# 30/30 - 0s - loss: 0.5191 - department_output_loss: 0.3293 - attrition_output_loss: 0.1898 - department_output_accuracy: 0.8777 - attrition_output_accuracy: 0.9309 - val_loss: 2.1311 - val_department_output_loss: 1.3508 - val_attrition_output_loss: 0.7804 - val_department_output_accuracy: 0.5763 - val_attrition_output_accuracy: 0.7754 - 138ms/epoch - 5ms/step

# %%
# Evaluate the model with the testing data

# Evaluate the model on the testing data again (if necessary) and print the results
evaluation_results = model.evaluate(
    X_test_scaled,
    [y_test_department_encoded, y_test_attrition_binary],
    verbose=2
)

# Print the full evaluation results
print("Evaluation Results:", evaluation_results)
# Out:
# 10/10 - 0s - loss: 1.6495 - department_output_loss: 1.1839 - attrition_output_loss: 0.4656 - department_output_accuracy: 0.6020 - attrition_output_accuracy: 0.8707 - 54ms/epoch - 5ms/step
# Evaluation Results: [1.6494961977005005, 1.1839412450790405, 0.46555495262145996, 0.6020408272743225, 0.8707482814788818]

# %%
# Print the accuracy for both department and attrition
# Assuming evaluation_results follows the structure:
# [total_loss, loss_department, accuracy_department, loss_attrition, accuracy_attrition]

# Correct indices after confirming the actual results structure
total_loss = evaluation_results[0]
accuracy_attrition = evaluation_results[1]
accuracy_department = evaluation_results[2]

# Print accuracies
print(f"Total Loss on Test Data: {total_loss:.2f}")
print(f"Accuracy for Attrition on Test Data: {accuracy_attrition*100:.2f}%")
print(f"Accuracy for Department on Test Data: {accuracy_department*100:.2f}%")
# Out:
# Total Loss on Test Data: 1.65
# Accuracy for Attrition on Test Data: 118.39%
# Accuracy for Department on Test Data: 46.56%

# %% [markdown]
# # Summary
#
# In the provided space below, briefly answer the following questions.
#
# 1. Is accuracy the best metric to use on this data? Why or why not?
#
# 2. What activation functions did you choose for your output layers, and why?
#
# 3. Can you name a few ways that this model might be improved?

# %% [markdown]
# YOUR ANSWERS HERE
#
# 1. Accuracy isn’t always the best measure for model performance, particularly with imbalanced datasets or when error costs differ. In attrition prediction, a skewed outcome (like more ‘No’ responses) could inflate accuracy, failing to spot employees likely to leave. Similarly, in department classification with varied class sizes, accuracy alone may not reflect true performance. Metrics like precision, recall, F1-score, and confusion matrices offer deeper insights, revealing potential class biases.
# 2. Attrition Output: Used sigmoid function for binary classification, providing a probability score perfect for ‘Yes’ or ‘No’ decisions.
# Department Output: Employed softmax function for multi-class classification, giving a probability for each class that totals to 1.
# 3. To enhance the model:
# Data Resampling: Use techniques like SMOTE to balance class distribution.
# Feature Engineering: Develop new metrics from existing data for better insights.
# Model Complexity: Increase layers or neurons to capture complex patterns.
# Regularization: Apply dropout or L1/L2 regularization to avoid overfitting.
# Hyperparameter Tuning: Optimize settings like learning rate and batch size for better results.
# Cross-validation: Employ k-fold cross-validation for a more accurate performance assessment.
# Evaluation Metrics: Utilize ROC-AUC and averaged metrics for deeper performance analysis.
# Additionally, ensemble methods could be explored to combine multiple models for improved accuracy and robustness.
